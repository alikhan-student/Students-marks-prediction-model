# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv(r'C:\New folder\linear_regression_data.csv')
df
# Out:
#     hours_studied  exam_score
# 0            3.75       16.41
# 1            9.51       32.92
# 2            7.32       27.14
# 3            5.99       18.98
# 4            1.56        9.24
# ..            ...         ...
# 95           4.94       18.18
# 96           5.23       20.53
# 97           4.28       18.51
# 98           0.25        6.32
# 99           1.08        9.89
#
# [100 rows x 2 columns]

# %%
plt.scatter(df['hours_studied'], df['exam_score'])
plt.xlabel('hours_studied')
plt.ylabel('exam_score')
plt.show()

# %%
lr=linear_model.LinearRegression()
lr.fit(df[['hours_studied']], df.exam_score)
# Out:
# LinearRegression()

# %%
lr.predict([[9]])
# Out:
# c:\Users\HP\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([31.60229118])

# %%
lr.score(df[['hours_studied']], df.exam_score)
# Out:
# 0.9582510734993261

# %%
plt.scatter(df['hours_studied'], df['exam_score'])
plt.xlabel('hours_studied')
plt.ylabel('exam_score')
plt.plot(df.hours_studied, lr.predict(df[['hours_studied']]),color='red')
plt.show()
